# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import numpy as np
from scipy import stats

# %%
df = pd.read_csv('data_simpsons_episodes.csv', encoding= 'unicode_escape')

# %%
df
# Out:
#       id                              title original_air_date production_code  \
# 0      1  Simpsons Roasting on an Open Fire        17-12-1989            7G08
# 1      2                    Bart the Genius        14-01-1990            7G02
# 2      3                    Homer's Odyssey        21-01-1990            7G03
# 3      4      There's No Disgrace Like Home        28-01-1990            7G04
# 4      5                   Bart the General        04-02-1990            7G05
# ..   ...                                ...               ...             ...
# 595  596           Orange Is the New Yellow        22-05-2016          VABF15
# 596  597        Monty Burns' Fleeing Circus        25-09-2016          VABF20
# 597  598           Friends and Family"[203]        02-10-2016          VABF18
# 598  599                     The Town"[205]        09-10-2016          VABF17
# 599  600    Treehouse of Horror XXVII"[207]        16-10-2016          VABF16
#
# ...

# %%
df['original_air_date'] = pd.to_datetime(df['original_air_date'], infer_datetime_format=True)

# %%
df
# Out:
#       id                              title original_air_date production_code  \
# 0      1  Simpsons Roasting on an Open Fire        1989-12-17            7G08
# 1      2                    Bart the Genius        1990-01-14            7G02
# 2      3                    Homer's Odyssey        1990-01-21            7G03
# 3      4      There's No Disgrace Like Home        1990-01-28            7G04
# 4      5                   Bart the General        1990-02-04            7G05
# ..   ...                                ...               ...             ...
# 595  596           Orange Is the New Yellow        2016-05-22          VABF15
# 596  597        Monty Burns' Fleeing Circus        2016-09-25          VABF20
# 597  598           Friends and Family"[203]        2016-10-02          VABF18
# 598  599                     The Town"[205]        2016-10-09          VABF17
# 599  600    Treehouse of Horror XXVII"[207]        2016-10-16          VABF16
#
# ...

# %%
df['original_air_date'] = pd.to_datetime(df['original_air_date'])

# %%
df['year'] = df['original_air_date'].dt.year
df['month'] = df['original_air_date'].dt.month
df['date'] = df['original_air_date'].dt.day
df['dayofweek']=df['original_air_date'].dt.day_name()

# %%
df
# Out:
#       id                              title original_air_date production_code  \
# 0      1  Simpsons Roasting on an Open Fire        1989-12-17            7G08
# 1      2                    Bart the Genius        1990-01-14            7G02
# 2      3                    Homer's Odyssey        1990-01-21            7G03
# 3      4      There's No Disgrace Like Home        1990-01-28            7G04
# 4      5                   Bart the General        1990-02-04            7G05
# ..   ...                                ...               ...             ...
# 595  596           Orange Is the New Yellow        2016-05-22          VABF15
# 596  597        Monty Burns' Fleeing Circus        2016-09-25          VABF20
# 597  598           Friends and Family"[203]        2016-10-02          VABF18
# 598  599                     The Town"[205]        2016-10-09          VABF17
# 599  600    Treehouse of Horror XXVII"[207]        2016-10-16          VABF16
#
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 600 entries, 0 to 599
# Data columns (total 18 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   id                      600 non-null    int64
#  1   title                   600 non-null    object
#  2   original_air_date       600 non-null    datetime64[ns]
#  3   production_code         600 non-null    object
#  4   season                  600 non-null    int64
#  5   number_in_season        600 non-null    int64
#  6   number_in_series        600 non-null    int64
#  7   us_viewers_in_millions  597 non-null    float64
#  8   views                   596 non-null    float64
#  9   imdb_rating             597 non-null    float64
#  10  imdb_votes              597 non-null    float64
#  11  image_url               596 non-null    object
#  12  video_url               596 non-null    object
#  13  year                    600 non-null    int64
# ...

# %%
df.isnull().sum().sort_values()
# Out:
# id                        0
# date                      0
# month                     0
# year                      0
# dayofweek                 0
# number_in_series          0
# weekofyear                0
# season                    0
# production_code           0
# original_air_date         0
# title                     0
# number_in_season          0
# us_viewers_in_millions    3
# imdb_rating               3
# imdb_votes                3
# image_url                 4
# video_url                 4
# views                     4
# dtype: int64

# %%
df['us_viewers_in_millions'].unique()
# Out:
# array([26.7 , 24.5 , 27.5 , 20.2 , 27.1 , 27.4 , 27.6 , 28.  , 33.5 ,
#        30.3 , 31.2 , 30.4 , 33.6 , 29.9 , 26.1 , 25.4 , 25.9 , 26.2 ,
#        22.2 , 24.8 , 24.2 , 26.8 , 23.9 , 21.2 , 20.6 , 17.7 , 19.7 ,
#        21.  , 17.3 , 22.9 , 22.8 , 20.8 , 20.  , 23.  , 24.7 , 21.1 ,
#        21.9 , 23.2 , 23.7 , 20.5 , 24.6 , 23.4 , 25.5 , 17.5 , 19.5 ,
#        17.2 , 21.8 , 18.3 , 19.3 , 19.  , 25.1 , 20.1 , 23.1 , 24.  ,
#        28.6 , 23.6 , 23.8 , 25.2 , 25.7 , 22.4 , 19.4 , 19.9 , 18.1 ,
#        21.7 , 18.7 , 17.9 , 18.2 , 18.  , 17.  , 14.7 , 15.5 , 15.1 ,
#        15.6 , 16.7 , 13.5 , 14.8 , 14.4 , 15.3 , 14.1 , 17.6 , 18.9 ,
#        11.6 , 11.8 , 12.6 , 12.7 , 13.1 , 15.  , 16.  , 15.7 , 14.5 ,
#        14.6 , 14.2 , 16.4 , 16.5 , 13.4 , 12.9 , 10.5 , 13.  , 11.3 ,
#        13.9 , 12.8 ,   nan, 14.9 , 20.9 , 14.  ,  9.1 , 13.3 , 16.9 ,
#        10.9 , 10.3 , 10.6 , 11.4 ,  9.3 ,  9.6 ,  8.9 , 11.7 ,  9.4 ,
# ...

# %%
df['imdb_rating'].unique()
# Out:
# array([8.2, 7.8, 7.5, 8.1, 7.6, 7.9, 7.7, 7.4, 8.3, 8. , 8.4, 8.8, 8.5,
#        8.6, 8.7, 9. , 7.2, 8.9, 6. , 9.1, 9.2, 7.3, 5.1, 6.9, 7.1, 6.6,
#        7. , 6.5, 5.6, 6.8, 6.7, 6.2, 6.4, 6.3, 6.1, 5.9, 5.7, 4.5, 5.8,
#        nan])

# %%
df['imdb_votes'].unique()
# Out:
# array([3734., 1973., 1709., 1701., 1732., 1674., 1638., 1580., 1578.,
#        1511., 1539., 1716., 1567., 1588., 1786., 1457., 1381., 1366.,
#        1324., 1522., 1402., 1340., 1687., 1392., 1329., 1241., 1413.,
#        1264., 1243., 1257., 1684., 1246., 1379., 1223., 1798., 1274.,
#        1302., 1446., 1452., 1262., 1369., 1194., 1618., 1291., 1213.,
#        1365., 1179., 1176., 1272., 1637., 1201., 1165., 1233., 1160.,
#        1227., 1414., 1339., 1747., 1394., 1293., 1163., 1240., 1595.,
#        1350., 1445., 2028., 1153., 1268., 1209., 1827., 1105., 1122.,
#        1234., 1080., 1269., 1416., 2010., 1476., 1479., 1437., 1132.,
#        1085., 1270., 1308., 1202., 1123., 1171., 1187., 1505., 1191.,
#        1116., 1143., 1118., 1103., 1014., 1060., 1330., 1156., 1051.,
#        1277., 1142., 1690., 1150., 1236., 1655., 1100., 1284., 1221.,
#        1254., 1353., 1006., 1190., 1004., 1084., 1003., 1285., 1619.,
# ...

# %%
df.isnull().sum().sort_values()
# Out:
# id                        0
# date                      0
# month                     0
# year                      0
# dayofweek                 0
# number_in_series          0
# weekofyear                0
# season                    0
# production_code           0
# original_air_date         0
# title                     0
# number_in_season          0
# us_viewers_in_millions    3
# imdb_rating               3
# imdb_votes                3
# image_url                 4
# video_url                 4
# views                     4
# dtype: int64

# %% [markdown]
# fillna null value using medium

# %%
df['us_viewers_in_millions']=df['us_viewers_in_millions'].fillna((df['us_viewers_in_millions'].median()))
df['imdb_rating']=df['imdb_rating'].fillna((df['imdb_rating'].median()))
df['views']=df['views'].fillna((df['views'].median()))
df['imdb_votes']=df['imdb_votes'].fillna((df['imdb_votes'].median()))

# %%
df.isnull().sum().sort_values()
# Out:
# id                        0
# date                      0
# month                     0
# year                      0
# imdb_votes                0
# imdb_rating               0
# dayofweek                 0
# views                     0
# number_in_series          0
# number_in_season          0
# season                    0
# production_code           0
# original_air_date         0
# title                     0
# us_viewers_in_millions    0
# weekofyear                0
# image_url                 4
# video_url                 4
# dtype: int64

# %%
df['image_url'].unique()
# Out:
# array(['http://static-media.fxx.com/img/FX_Networks_-_FXX/617/479/Simpsons_01_08.jpg',
#        'http://static-media.fxx.com/img/FX_Networks_-_FXX/265/167/Simpsons_01_02.jpg',
#        'http://static-media.fxx.com/img/FX_Networks_-_FXX/621/883/Simpsons_01_03.jpg',
#        'http://static-media.fxx.com/img/FX_Networks_-_FXX/632/119/Simpsons_01_04__343617.jpg',
#        'http://static-media.fxx.com/img/FX_Networks_-_FXX/274/735/Simpsons_01_05.jpg',
#        'http://static-media.fxx.com/img/FX_Networks_-_FXX/631/642/Simpsons_01_06.jpg',
#        'http://static-media.fxx.com/img/FX_Networks_-_FXX/636/523/Simpsons_01_09__827207.jpg',
#        'http://static-media.fxx.com/img/FX_Networks_-_FXX/688/495/Simpsons_01_07__906920.jpg',
#        'http://static-media.fxx.com/img/FX_Networks_-_FXX/132/587/Simpsons_01_11.jpg',
#        'http://static-media.fxx.com/img/FX_Networks_-_FXX/305/815/Simpsons_01_10.jpg',
# ...

# %%
df = df.dropna()

# %%
df
# Out:
#       id                              title original_air_date production_code  \
# 0      1  Simpsons Roasting on an Open Fire        1989-12-17            7G08
# 1      2                    Bart the Genius        1990-01-14            7G02
# 2      3                    Homer's Odyssey        1990-01-21            7G03
# 3      4      There's No Disgrace Like Home        1990-01-28            7G04
# 4      5                   Bart the General        1990-02-04            7G05
# ..   ...                                ...               ...             ...
# 592  593                       Fland Canyon        2016-04-24          VABF12
# 593  594               To Courier with Love        2016-05-08          VABF14
# 594  595                        Simprovised        2016-05-15          VABF13
# 595  596           Orange Is the New Yellow        2016-05-22          VABF15
# 596  597        Monty Burns' Fleeing Circus        2016-09-25          VABF20
#
# ...

# %%
df.isnull().sum().sort_values()
# Out:
# id                        0
# date                      0
# month                     0
# year                      0
# video_url                 0
# image_url                 0
# imdb_votes                0
# imdb_rating               0
# views                     0
# us_viewers_in_millions    0
# number_in_series          0
# number_in_season          0
# season                    0
# production_code           0
# original_air_date         0
# title                     0
# dayofweek                 0
# weekofyear                0
# dtype: int64

# %%
df
# Out:
#       id                              title original_air_date production_code  \
# 0      1  Simpsons Roasting on an Open Fire        1989-12-17            7G08
# 1      2                    Bart the Genius        1990-01-14            7G02
# 2      3                    Homer's Odyssey        1990-01-21            7G03
# 3      4      There's No Disgrace Like Home        1990-01-28            7G04
# 4      5                   Bart the General        1990-02-04            7G05
# ..   ...                                ...               ...             ...
# 592  593                       Fland Canyon        2016-04-24          VABF12
# 593  594               To Courier with Love        2016-05-08          VABF14
# 594  595                        Simprovised        2016-05-15          VABF13
# 595  596           Orange Is the New Yellow        2016-05-22          VABF15
# 596  597        Monty Burns' Fleeing Circus        2016-09-25          VABF20
#
# ...

# %%
plt.rcParams["figure.figsize"] = (20,10)

# %%
sns.countplot(x=df['season'], data=df)
# Out:
# <AxesSubplot:xlabel='season', ylabel='count'>

# %%
sns.countplot(x=df['number_in_season'], data=df)
# Out:
# <AxesSubplot:xlabel='number_in_season', ylabel='count'>

# %%
sns.distplot(df['number_in_series'])
df['number_in_series'].skew()
# Out:
# C:\Users\SanthoshkumarSambamo\anaconda3\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# 0.003268021672226913

# %%
sns.distplot(df['us_viewers_in_millions'])
df['us_viewers_in_millions'].skew()
# Out:
# C:\Users\SanthoshkumarSambamo\anaconda3\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# 0.8861164056612405

# %%
sns.distplot(df['views'])
df['views'].skew()
# Out:
# C:\Users\SanthoshkumarSambamo\anaconda3\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# 0.5758100156934226

# %%
sns.countplot(x=df['imdb_rating'], data=df)
# Out:
# <AxesSubplot:xlabel='imdb_rating', ylabel='count'>

# %%
sns.distplot(df['imdb_votes'])
df['imdb_votes'].skew()
# Out:
# C:\Users\SanthoshkumarSambamo\anaconda3\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# 1.4580947273105926

# %%
df
# Out:
#       id                              title original_air_date production_code  \
# 0      1  Simpsons Roasting on an Open Fire        1989-12-17            7G08
# 1      2                    Bart the Genius        1990-01-14            7G02
# 2      3                    Homer's Odyssey        1990-01-21            7G03
# 3      4      There's No Disgrace Like Home        1990-01-28            7G04
# 4      5                   Bart the General        1990-02-04            7G05
# ..   ...                                ...               ...             ...
# 592  593                       Fland Canyon        2016-04-24          VABF12
# 593  594               To Courier with Love        2016-05-08          VABF14
# 594  595                        Simprovised        2016-05-15          VABF13
# 595  596           Orange Is the New Yellow        2016-05-22          VABF15
# 596  597        Monty Burns' Fleeing Circus        2016-09-25          VABF20
#
# ...

# %%
value = ['season', 'number_in_season', 'date', 'dayofweek', 'weekofyear','imdb_rating']

# %%
f = pd.melt(df, value_vars=value)
g = sns.FacetGrid(f, col="variable", col_wrap=3, sharex=False, sharey=False, size = 5)
g = g.map(sns.countplot, "value")
# Out:
# C:\Users\SanthoshkumarSambamo\anaconda3\lib\site-packages\seaborn\axisgrid.py:337: UserWarning: The `size` parameter has been renamed to `height`; please update your code.
#   warnings.warn(msg, UserWarning)
# C:\Users\SanthoshkumarSambamo\anaconda3\lib\site-packages\seaborn\axisgrid.py:670: UserWarning: Using the countplot function without specifying `order` is likely to produce an incorrect plot.
#   warnings.warn(warning)

# %%
values = ['number_in_series','us_viewers_in_millions','views','imdb_votes']

# %%
f = pd.melt(df, value_vars=values)
g = sns.FacetGrid(f, col="variable",  col_wrap=3, sharex=False, sharey=False, height = 5)
g = g.map(sns.distplot, "value")
# Out:
# C:\Users\SanthoshkumarSambamo\anaconda3\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# C:\Users\SanthoshkumarSambamo\anaconda3\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# ...

# %%
sns.barplot(x='season',y='number_in_series',data=df)
# Out:
# <AxesSubplot:xlabel='season', ylabel='number_in_series'>

# %%
sns.barplot(x='season',y='number_in_season',data=df)
# Out:
# <AxesSubplot:xlabel='season', ylabel='number_in_season'>

# %%
sns.barplot(x='season',y='us_viewers_in_millions',data=df)
# Out:
# <AxesSubplot:xlabel='season', ylabel='us_viewers_in_millions'>

# %%
sns.barplot(x='month',y='us_viewers_in_millions',data=df)
# Out:
# <AxesSubplot:xlabel='month', ylabel='us_viewers_in_millions'>

# %%
sns.barplot(x='month',y='views',data=df)
# Out:
# <AxesSubplot:xlabel='month', ylabel='views'>

# %%
sns.boxplot(x='year', y='views', data=df)
# Out:
# <AxesSubplot:xlabel='year', ylabel='views'>

# %%
sns.catplot(x='month', y='views', data=df)

# %%
sns.swarmplot(x='year', y='us_viewers_in_millions', data=df)
# Out:
# <AxesSubplot:xlabel='year', ylabel='us_viewers_in_millions'>

# %%
sns.violinplot(y='year', hue='views',data=df, 
               split=True
              );

# %%
corr = df.corr()
sns.heatmap(corr, annot=True)
# Out:
# <AxesSubplot:>

# %%
sns.scatterplot(x='', y='views', hue='year', data=train)
